# %% [markdown]
# # Mouvement et énergies dans un champ uniforme

# %% [markdown]
# En utilisant le menu indiqué sur l'image ci-dessous
#
# ![chute_parabolique_1.jpg](attachment:chute_parabolique_1.jpg)
#
# déposez le fichier `chute_parabolique.txt`
#
# Vous devez obtenir ceci :
#
# ![chute_parabolique_2.jpg](attachment:chute_parabolique_2.jpg)

# %% [markdown]
# > **Travail à faire** : Exécutez la cellule ci-dessous pour importer les modules nécessaires

# %%
import csv
import matplotlib.pyplot as plt

#Création de quatre listes contenant le temps, la valeur de x, la valeur de y, la valeur de la vitesse
t = [] 
x = []
y = []
v = []

with open('chute_parabolique.txt', newline='') as csvfile:
    file = list(csv.DictReader(csvfile, delimiter=";"))
    for ligne in file:
        t.append(float(ligne['temps']))
        x.append(float(ligne['x']))
        y.append(float(ligne['y']))
        v.append(float(ligne['v']))

# %% [markdown]
# <div class="alert alert-danger">Enregistrez votre travail</div>

# %% [markdown]
# ---
# ## 2. Tir parabolique

# %% [markdown]
# > **Travail à faire** : dans la cellule ci-dessous, complétez le code
# > en indiquant les calculs qui permettent d'obtenir les valeurs de :
# > - l'énergie cinétique à l'instant $t_i$
# > - l'énergie potentielle à l'instant $t_i$
# > - l'énergie mécanique à l'instant $t_i$
# >
# >puis cliquez sur `Run`

# %%
#On definit les listes que l'on va créer
tg, Ec, Em, Ep= [], [], [], []

# dans une boucle, on parcourt la liste de t et y pour calculer les differentes valeurs de v, Ec, Ep, Em
for i in range(0, len(y)-1):
    Eci = ...
    Epi = ...
    Emi = ...
    
    # On stocke chaque valeur dans les listes
    Ec.append(Eci)
    Ep.append(Epi)
    Em.append(Emi)
    tg.append(t[i])

# %% [markdown]
# > **Travail à faire** : exécutez la cellule ci-dessous pour tracer les courbes

# %%
# on efface la fenêtre
plt.clf()

#On trace les trois courbes d'energie
plt.plot(tg, Ec, 'or', tg, Ep, 'ob', tg, Em, 'og')

# On ajoute un titre pour chaque axe et pour le graphique
plt.xlabel("temps t (en s)")
plt.ylabel("Energie (en J)")
plt.show()
plt.close()

# %% [markdown]
# <div class="alert alert-danger">Enregistrez votre travail</div>
