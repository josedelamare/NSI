# %% [markdown]
# # Débuter en Markdown

# %% [markdown]
# ## Mise en forme du texte

# %% [markdown]
# *Texte en italique*
#
# **Texte en gras**
#
# ***Texte en italique et en gras***
#
# ~~Ce texte est barré.~~

# %% [markdown]
# ## Les citations

# %% [markdown]
# >Ceci est une **zone en retrait**.
# >La zone continue ici
#
# >Ceci est une autre zone de retrait

# %% [markdown]
# ## Les paragraphes

# %% [markdown]
# Un premier paragraphe
# qui s'arrête si on saute une ligne.
#
# Le deuxième paragraphe continue ici.

# %% [markdown]
# ## Les listes

# %% [markdown]
# - Liste1
# - Liste 2
# - Liste 3

# %% [markdown]
# 1. Liste1
# 2. Liste 2
# 3. Liste 3

# %% [markdown]
# ## Inclure du code

# %% [markdown]
# C’est le `code`.

# %% [markdown]
# Du Python au milieu du texte
# ```python
# a = 3
# b = 2
# print(a + b)
# ```

# %% [markdown]
# ## les images

# %% [markdown]
# Insertion par glissé-deposé
#
# ![notebook-2.jpg](attachment:notebook-2.jpg)

# %% [markdown]
# ## Les hyperliens

# %% [markdown]
# [titre de lien optionnel](https://github.com/josedelamare/ "titre visible au survol de la souris")

# %% [markdown]
# ## Des boîtes colorées

# %% [markdown]
# <div class="alert alert-success"> This is a success box, color = green </div>

# %% [markdown]
# <div class="alert alert-info"> This is an info box, color = blue </div>

# %% [markdown]
# <div class="alert alert-warning"> This is a warning box, color = orange </div>

# %% [markdown]
# <div class="alert alert-danger"> This is a danger box, color = red </div>
